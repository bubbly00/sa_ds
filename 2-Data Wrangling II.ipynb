# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Academic-Performance-Dataset.csv")
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0       62.0       98.0
# 1        2    Reyansh      M     IT        58.0       62.0       83.0
# 2        3      Aarav      M     IT        57.0      -20.0      100.0
# 3        4     Atharv      M     IT        60.0       89.0       83.0
# 4        5     Vivaan      M   Comp        85.0       90.0        NaN
# 5        6      Advik      M   ENTC        94.0       99.0       84.0
# 6        7       Ansh      M   ENTC        98.0       88.0       95.0
# 7        8     Ishaan      M   ENTC        75.0       66.0       51.0
# 8        9      Dhruv      M   ENTC        63.0        NaN        NaN
# 9       10  Siddharth      M   ENTC        96.0       67.0       78.0
# 10      11     Vihaan      M   ENTC        82.0       54.0       70.0
# 11      12        NaN      M     IT        75.0       64.0       67.0
# 12      13     Aarush      M     IT        67.0       56.0       81.0
# 13      14        Leo      M     IT        98.0      -34.0       70.0
# 14      15     Maryam      F     IT        64.0       87.0       60.0
# 15      16     Saanvi      F   Comp        66.0       90.0       95.0
# 16      17    Zaranew      F   Comp        93.0       54.0        NaN
# 17      18      Inaya      F   Comp        74.0       67.0       93.0
# 18      19      Aarya      F   Comp        72.0       88.0       84.0
# 19      20        NaN      F   Comp        53.0       76.0       81.0
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# 0        63.0       89.0       36.0          368        73.6
# 1        83.0       88.0       34.0          350        70.0
# 2         NaN       56.0       36.0          192        38.4
# 3        70.0       33.0       23.0          298        59.6
# 4        78.0       23.0       56.0          247        49.4
# 5       100.0       56.0       99.0          438        87.6
# 6        81.0       78.0       78.0          420        84.0
# 7        83.0      -99.0       76.0          192        38.4
# 8        97.0       56.0       55.0          208        41.6
# 9        95.0        NaN       98.0          338        67.6
# 10       88.0       55.0       56.0          323        64.6
# 11       71.0       66.0       87.0          355        71.0
# 12        NaN       90.0       55.0          282        56.4
# 13       94.0       77.0       66.0          273        54.6
# 14       90.0       65.0       90.0          392        78.4
# 15       67.0       99.0       77.0          428        85.6
# 16       75.0       90.0       65.0          284        56.8
# 17       93.0       87.0       99.0          439        87.8
# 18       81.0       80.0       45.0          378        75.6
# 19       93.0       65.0       23.0          338        67.6

# %%
df.shape
# Out:
# (20, 12)

# %%
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0       62.0       98.0
# 1        2    Reyansh      M     IT        58.0       62.0       83.0
# 2        3      Aarav      M     IT        57.0      -20.0      100.0
# 3        4     Atharv      M     IT        60.0       89.0       83.0
# 4        5     Vivaan      M   Comp        85.0       90.0        NaN
# 5        6      Advik      M   ENTC        94.0       99.0       84.0
# 6        7       Ansh      M   ENTC        98.0       88.0       95.0
# 7        8     Ishaan      M   ENTC        75.0       66.0       51.0
# 8        9      Dhruv      M   ENTC        63.0        NaN        NaN
# 9       10  Siddharth      M   ENTC        96.0       67.0       78.0
# 10      11     Vihaan      M   ENTC        82.0       54.0       70.0
# 11      12        NaN      M     IT        75.0       64.0       67.0
# 12      13     Aarush      M     IT        67.0       56.0       81.0
# 13      14        Leo      M     IT        98.0      -34.0       70.0
# 14      15     Maryam      F     IT        64.0       87.0       60.0
# 15      16     Saanvi      F   Comp        66.0       90.0       95.0
# 16      17    Zaranew      F   Comp        93.0       54.0        NaN
# 17      18      Inaya      F   Comp        74.0       67.0       93.0
# 18      19      Aarya      F   Comp        72.0       88.0       84.0
# 19      20        NaN      F   Comp        53.0       76.0       81.0
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# 0        63.0       89.0       36.0          368        73.6
# 1        83.0       88.0       34.0          350        70.0
# 2         NaN       56.0       36.0          192        38.4
# 3        70.0       33.0       23.0          298        59.6
# 4        78.0       23.0       56.0          247        49.4
# 5       100.0       56.0       99.0          438        87.6
# 6        81.0       78.0       78.0          420        84.0
# 7        83.0      -99.0       76.0          192        38.4
# 8        97.0       56.0       55.0          208        41.6
# 9        95.0        NaN       98.0          338        67.6
# 10       88.0       55.0       56.0          323        64.6
# 11       71.0       66.0       87.0          355        71.0
# 12        NaN       90.0       55.0          282        56.4
# 13       94.0       77.0       66.0          273        54.6
# 14       90.0       65.0       90.0          392        78.4
# 15       67.0       99.0       77.0          428        85.6
# 16       75.0       90.0       65.0          284        56.8
# 17       93.0       87.0       99.0          439        87.8
# 18       81.0       80.0       45.0          378        75.6
# 19       93.0       65.0       23.0          338        67.6

# %%
df.dtypes
# Out:
# Rollno           int64
# Name            object
# Gender          object
# Branch          object
# Attendence     float64
# Phy_marks      float64
# Che_marks      float64
# EM1_marks      float64
# PPS_marks      float64
# SME_marks      float64
# Total Marks      int64
# Percentage     float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Rollno         0
# Name           2
# Gender         0
# Branch         0
# Attendence     0
# Phy_marks      1
# Che_marks      3
# EM1_marks      2
# PPS_marks      1
# SME_marks      0
# Total Marks    0
# Percentage     0
# dtype: int64

# %%
df.isnull()
# Out:
#     Rollno   Name  Gender  Branch  Attendence  Phy_marks  Che_marks  \
# 0    False  False   False   False       False      False      False
# 1    False  False   False   False       False      False      False
# 2    False  False   False   False       False      False      False
# 3    False  False   False   False       False      False      False
# 4    False  False   False   False       False      False       True
# 5    False  False   False   False       False      False      False
# 6    False  False   False   False       False      False      False
# 7    False  False   False   False       False      False      False
# 8    False  False   False   False       False       True       True
# 9    False  False   False   False       False      False      False
# 10   False  False   False   False       False      False      False
# 11   False   True   False   False       False      False      False
# 12   False  False   False   False       False      False      False
# 13   False  False   False   False       False      False      False
# 14   False  False   False   False       False      False      False
# 15   False  False   False   False       False      False      False
# 16   False  False   False   False       False      False       True
# 17   False  False   False   False       False      False      False
# 18   False  False   False   False       False      False      False
# 19   False   True   False   False       False      False      False
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# 0       False      False      False        False       False
# 1       False      False      False        False       False
# 2        True      False      False         True        True
# 3       False      False      False        False       False
# 4       False      False      False         True        True
# 5       False      False      False        False       False
# 6       False      False      False        False       False
# 7       False      False      False        False       False
# 8       False      False      False         True        True
# 9       False       True      False         True        True
# 10      False      False      False        False       False
# 11      False      False      False        False       False
# 12       True      False      False         True        True
# 13      False      False      False        False       False
# 14      False      False      False        False       False
# 15      False      False      False        False       False
# 16      False      False      False         True        True
# 17      False      False      False        False       False
# 18      False      False      False        False       False
# 19      False      False      False        False       False

# %%
cols_with_na = []
for col in df.columns:
    if df[col].isna().any():
        cols_with_na.append(col)

cols_with_na
# Out:
# ['Name', 'Phy_marks', 'Che_marks', 'EM1_marks', 'PPS_marks']

# %%
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0       62.0       98.0
# 1        2    Reyansh      M     IT        58.0       62.0       83.0
# 2        3      Aarav      M     IT        57.0      -20.0      100.0
# 3        4     Atharv      M     IT        60.0       89.0       83.0
# 4        5     Vivaan      M   Comp        85.0       90.0        NaN
# 5        6      Advik      M   ENTC        94.0       99.0       84.0
# 6        7       Ansh      M   ENTC        98.0       88.0       95.0
# 7        8     Ishaan      M   ENTC        75.0       66.0       51.0
# 8        9      Dhruv      M   ENTC        63.0        NaN        NaN
# 9       10  Siddharth      M   ENTC        96.0       67.0       78.0
# 10      11     Vihaan      M   ENTC        82.0       54.0       70.0
# 11      12        NaN      M     IT        75.0       64.0       67.0
# 12      13     Aarush      M     IT        67.0       56.0       81.0
# 13      14        Leo      M     IT        98.0      -34.0       70.0
# 14      15     Maryam      F     IT        64.0       87.0       60.0
# 15      16     Saanvi      F   Comp        66.0       90.0       95.0
# 16      17    Zaranew      F   Comp        93.0       54.0        NaN
# 17      18      Inaya      F   Comp        74.0       67.0       93.0
# 18      19      Aarya      F   Comp        72.0       88.0       84.0
# 19      20        NaN      F   Comp        53.0       76.0       81.0
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# 0        63.0       89.0       36.0          368        73.6
# 1        83.0       88.0       34.0          350        70.0
# 2         NaN       56.0       36.0          192        38.4
# 3        70.0       33.0       23.0          298        59.6
# 4        78.0       23.0       56.0          247        49.4
# 5       100.0       56.0       99.0          438        87.6
# 6        81.0       78.0       78.0          420        84.0
# 7        83.0      -99.0       76.0          192        38.4
# 8        97.0       56.0       55.0          208        41.6
# 9        95.0        NaN       98.0          338        67.6
# 10       88.0       55.0       56.0          323        64.6
# 11       71.0       66.0       87.0          355        71.0
# 12        NaN       90.0       55.0          282        56.4
# 13       94.0       77.0       66.0          273        54.6
# 14       90.0       65.0       90.0          392        78.4
# 15       67.0       99.0       77.0          428        85.6
# 16       75.0       90.0       65.0          284        56.8
# 17       93.0       87.0       99.0          439        87.8
# 18       81.0       80.0       45.0          378        75.6
# 19       93.0       65.0       23.0          338        67.6

# %%
df.fillna("0")
# Out:
#     Rollno       Name Gender Branch  Attendence Phy_marks Che_marks EM1_marks  \
# 0        1   Mohammed      M   Comp        72.0      62.0      98.0      63.0
# 1        2    Reyansh      M     IT        58.0      62.0      83.0      83.0
# 2        3      Aarav      M     IT        57.0     -20.0     100.0         0
# 3        4     Atharv      M     IT        60.0      89.0      83.0      70.0
# 4        5     Vivaan      M   Comp        85.0      90.0         0      78.0
# 5        6      Advik      M   ENTC        94.0      99.0      84.0     100.0
# 6        7       Ansh      M   ENTC        98.0      88.0      95.0      81.0
# 7        8     Ishaan      M   ENTC        75.0      66.0      51.0      83.0
# 8        9      Dhruv      M   ENTC        63.0         0         0      97.0
# 9       10  Siddharth      M   ENTC        96.0      67.0      78.0      95.0
# 10      11     Vihaan      M   ENTC        82.0      54.0      70.0      88.0
# 11      12          0      M     IT        75.0      64.0      67.0      71.0
# 12      13     Aarush      M     IT        67.0      56.0      81.0         0
# 13      14        Leo      M     IT        98.0     -34.0      70.0      94.0
# 14      15     Maryam      F     IT        64.0      87.0      60.0      90.0
# 15      16     Saanvi      F   Comp        66.0      90.0      95.0      67.0
# 16      17    Zaranew      F   Comp        93.0      54.0         0      75.0
# 17      18      Inaya      F   Comp        74.0      67.0      93.0      93.0
# 18      19      Aarya      F   Comp        72.0      88.0      84.0      81.0
# 19      20          0      F   Comp        53.0      76.0      81.0      93.0
#
#    PPS_marks  SME_marks  Total Marks  Percentage
# 0       89.0       36.0          368        73.6
# 1       88.0       34.0          350        70.0
# 2       56.0       36.0          192        38.4
# 3       33.0       23.0          298        59.6
# 4       23.0       56.0          247        49.4
# 5       56.0       99.0          438        87.6
# 6       78.0       78.0          420        84.0
# 7      -99.0       76.0          192        38.4
# 8       56.0       55.0          208        41.6
# 9          0       98.0          338        67.6
# 10      55.0       56.0          323        64.6
# 11      66.0       87.0          355        71.0
# 12      90.0       55.0          282        56.4
# 13      77.0       66.0          273        54.6
# 14      65.0       90.0          392        78.4
# 15      99.0       77.0          428        85.6
# 16      90.0       65.0          284        56.8
# 17      87.0       99.0          439        87.8
# 18      80.0       45.0          378        75.6
# 19      65.0       23.0          338        67.6

# %%
df['Total Marks']=df['Phy_marks']+df['Che_marks']+df['EM1_marks']+df['PPS_marks']+df['SME_marks']
df['Percentage']=df['Total Marks']/5
df.fillna(0)
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0       62.0       98.0
# 1        2    Reyansh      M     IT        58.0       62.0       83.0
# 2        3      Aarav      M     IT        57.0      -20.0      100.0
# 3        4     Atharv      M     IT        60.0       89.0       83.0
# 4        5     Vivaan      M   Comp        85.0       90.0        0.0
# 5        6      Advik      M   ENTC        94.0       99.0       84.0
# 6        7       Ansh      M   ENTC        98.0       88.0       95.0
# 7        8     Ishaan      M   ENTC        75.0       66.0       51.0
# 8        9      Dhruv      M   ENTC        63.0        0.0        0.0
# 9       10  Siddharth      M   ENTC        96.0       67.0       78.0
# 10      11     Vihaan      M   ENTC        82.0       54.0       70.0
# 11      12          0      M     IT        75.0       64.0       67.0
# 12      13     Aarush      M     IT        67.0       56.0       81.0
# 13      14        Leo      M     IT        98.0      -34.0       70.0
# 14      15     Maryam      F     IT        64.0       87.0       60.0
# 15      16     Saanvi      F   Comp        66.0       90.0       95.0
# 16      17    Zaranew      F   Comp        93.0       54.0        0.0
# 17      18      Inaya      F   Comp        74.0       67.0       93.0
# 18      19      Aarya      F   Comp        72.0       88.0       84.0
# 19      20          0      F   Comp        53.0       76.0       81.0
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# 0        63.0       89.0       36.0        348.0        69.6
# 1        83.0       88.0       34.0        350.0        70.0
# 2         0.0       56.0       36.0          0.0         0.0
# 3        70.0       33.0       23.0        298.0        59.6
# 4        78.0       23.0       56.0          0.0         0.0
# 5       100.0       56.0       99.0        438.0        87.6
# 6        81.0       78.0       78.0        420.0        84.0
# 7        83.0      -99.0       76.0        177.0        35.4
# 8        97.0       56.0       55.0          0.0         0.0
# 9        95.0        0.0       98.0          0.0         0.0
# 10       88.0       55.0       56.0        323.0        64.6
# 11       71.0       66.0       87.0        355.0        71.0
# 12        0.0       90.0       55.0          0.0         0.0
# 13       94.0       77.0       66.0        273.0        54.6
# 14       90.0       65.0       90.0        392.0        78.4
# 15       67.0       99.0       77.0        428.0        85.6
# 16       75.0       90.0       65.0          0.0         0.0
# 17       93.0       87.0       99.0        439.0        87.8
# 18       81.0       80.0       45.0        378.0        75.6
# 19       93.0       65.0       23.0        338.0        67.6

# %%
import matplotlib.pyplot as plt
col = ['Attendence', 'Phy_marks' , 'Che_marks','Percentage']
df.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df
# Out:
#     Rollno       Name  Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed       1   Comp        72.0       62.0       98.0
# 1        2    Reyansh       1     IT        58.0       62.0       83.0
# 2        3      Aarav       1     IT        57.0      -20.0      100.0
# 3        4     Atharv       1     IT        60.0       89.0       83.0
# 4        5     Vivaan       1   Comp        85.0       90.0        NaN
# 5        6      Advik       1   ENTC        94.0       99.0       84.0
# 6        7       Ansh       1   ENTC        98.0       88.0       95.0
# 7        8     Ishaan       1   ENTC        75.0       66.0       51.0
# 8        9      Dhruv       1   ENTC        63.0        NaN        NaN
# 9       10  Siddharth       1   ENTC        96.0       67.0       78.0
# 10      11     Vihaan       1   ENTC        82.0       54.0       70.0
# 11      12        NaN       1     IT        75.0       64.0       67.0
# 12      13     Aarush       1     IT        67.0       56.0       81.0
# 13      14        Leo       1     IT        98.0      -34.0       70.0
# 14      15     Maryam       0     IT        64.0       87.0       60.0
# 15      16     Saanvi       0   Comp        66.0       90.0       95.0
# 16      17    Zaranew       0   Comp        93.0       54.0        NaN
# 17      18      Inaya       0   Comp        74.0       67.0       93.0
# 18      19      Aarya       0   Comp        72.0       88.0       84.0
# 19      20        NaN       0   Comp        53.0       76.0       81.0
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# 0        63.0       89.0       36.0        348.0        69.6
# 1        83.0       88.0       34.0        350.0        70.0
# 2         NaN       56.0       36.0          NaN         NaN
# 3        70.0       33.0       23.0        298.0        59.6
# 4        78.0       23.0       56.0          NaN         NaN
# 5       100.0       56.0       99.0        438.0        87.6
# 6        81.0       78.0       78.0        420.0        84.0
# 7        83.0      -99.0       76.0        177.0        35.4
# 8        97.0       56.0       55.0          NaN         NaN
# 9        95.0        NaN       98.0          NaN         NaN
# 10       88.0       55.0       56.0        323.0        64.6
# 11       71.0       66.0       87.0        355.0        71.0
# 12        NaN       90.0       55.0          NaN         NaN
# 13       94.0       77.0       66.0        273.0        54.6
# 14       90.0       65.0       90.0        392.0        78.4
# 15       67.0       99.0       77.0        428.0        85.6
# 16       75.0       90.0       65.0          NaN         NaN
# 17       93.0       87.0       99.0        439.0        87.8
# 18       81.0       80.0       45.0        378.0        75.6
# 19       93.0       65.0       23.0        338.0        67.6
